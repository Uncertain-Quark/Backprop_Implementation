# %%
import numpy as np
import pandas as pd
import itertools
import time
import matplotlib.pyplot as plt

### Definition of all the activation functions ###
def tan_hyp(y) :
    return np.tanh(y)

def softmax(y) :
    return np.exp(y-max(y))/np.sum(np.exp(y-max(y)))

def linear(y) : 
    return y

### Derivatives of the activation functions ###

def der_softmax(y) : 
    a = np.zeros((len(y),len(y)))
    np.fill_diagonal(a,y)
    y = np.reshape(y,(len(y),-1))
    b = np.dot(y,np.transpose(y))
    return a - b

def der_tan_hyp(y) : 
    return (1-y)*(1+y)

def der_linear(y) :
    a = np.zeros((len(y),len(y)))
    np.fill_diagonal(a,y)
    return a

### Definition of loss functions for a single example ###
def mse(y,t) : 
    return 0.5*np.sum((y-t)**2)

def cross_entropy(y,t):
    return -np.sum(t*np.log(y))

def grad_cross_entropy(y,t) :
    return -np.divide(t,y)

def grad_mse(y,t) : 
    return y-t

def forward_pass_customweights(activation_functions,training_sample,w) : 
        a_list = [training_sample]
        h_list = [training_sample]
        output = training_sample
        
        for (activation_function,weight) in zip(activation_functions,w) :
            
            output = np.append(output,np.ones((1,1)),axis = 0)
            output = np.dot(weight,output)
            a_list.append(output)
            
            output = eval(activation_function)(output)
            h_list.append(output)
        return a_list , h_list

# %%
###class definition
class neural_network :
    
    def __init__(self, n_hidden,list_nodes,loss_fn,list_activation_functions,learning_rate,momentum) :
        self.n_hidden = n_hidden
        self.list_nodes = list_nodes
        self.loss_fn = loss_fn
        self.list_activation_functions = list_activation_functions
        self.learning_rate = learning_rate
        self.momentum = momentum
        self.weights = []
        self.grad_past = []
        
        for i in range(n_hidden+1) :
            
            np.random.seed(42)
            weight_layer = np.random.randn(list_nodes[i+1],list_nodes[i]+1)
            grad_past_layer = np.zeros((list_nodes[i+1],list_nodes[i]+1))
            self.weights.append(weight_layer)
            self.grad_past.append(grad_past_layer)

    def forward_pass(self,training_sample):
        a_list = [training_sample]
        h_list = [training_sample]
        output = training_sample
        
        for (activation_function,weight) in zip(self.list_activation_functions,self.weights) :
            
            output = np.append(output,np.ones((1,1)),axis = 0)
            output = np.dot(weight,output)
            a_list.append(output)
            
            output = eval(activation_function)(output)
            h_list.append(output)
        return a_list , h_list
    
    def calc_loss(self,calc_output,actual_output) :
        return eval(self.loss_fn)(calc_output,actual_output)
    
    def backward_pass(self,h_list,intermediate_loss,actual_output) : 
        '''implementation of backpropagation'''
        
        der_output_act = eval('der_'+self.list_activation_functions[-1])(h_list[-1])
        grad_lf = eval('grad_'+self.loss_fn)(h_list[-1],actual_output)
        grad_layer = np.dot(der_output_act,grad_lf)
                
        for i in range(len(self.weights)) : 
            
            grad_weight_layer = np.dot(grad_layer,np.transpose(np.append(h_list[len(h_list)-i-2],np.ones((1,1)),axis = 0)))
            
            grad_prev_output = np.dot(np.transpose(self.weights[len(self.weights)-i-1])[:-1,:],grad_layer)
            grad_layer = grad_prev_output * eval('der_'+self.list_activation_functions[len(self.list_activation_functions)-i-2])(h_list[len(h_list)-i-2])
            
            self.weights[len(self.weights)-i-1] = self.gen_delta_rule(self.weights[len(self.weights)-i-1],grad_weight_layer,self.grad_past[len(self.grad_past)-i-1]) 
            self.grad_past[len(self.grad_past)-i-1] = self.learning_rate*grad_weight_layer
            
    def gen_delta_rule(self,weights_present,grad_present,weight_change_previous) :
        return weights_present - (grad_present*self.learning_rate) - (weight_change_previous*self.momentum)
    
    def train(self,input_array,output_array,valid_input_array,valid_output_array) : 
        loss_list = []
        valid_loss_list = []
        epoch_num = 0
        prev_loss_avg = 0
        loss_avg = 0
        
        while (epoch_num<=0 or abs(prev_loss_avg - loss_avg)>=1e-5) : 
            
            prev_loss_avg = loss_avg
            loss_avg = 0
                
            print('Epoch Number : ',epoch_num)
            print('Started')
            print('----------------------------------------')
            for (training_sample,actual_output) in zip(input_array,output_array) :
                
                a_list,h_list = self.forward_pass(training_sample)
                
                intermediate_loss = self.calc_loss(h_list[-1],actual_output)
                
                self.backward_pass(h_list,intermediate_loss,actual_output)
                
                loss_avg = loss_avg + intermediate_loss
            
            loss_avg = loss_avg/len(input_array)
            loss_list.append(loss_avg)
            
            valid_loss_avg = 0
            
            for (training_sample,actual_output) in zip(valid_input_array,valid_output_array) :
                
                a_list,h_list = self.forward_pass(training_sample)
                
                intermediate_loss = self.calc_loss(h_list[-1],actual_output)
                                
                valid_loss_avg = valid_loss_avg + intermediate_loss
            
            valid_loss_avg = valid_loss_avg/len(valid_input_array)
            valid_loss_list.append(valid_loss_avg)
            
            print('Average Loss : ',loss_avg)    
            print('----------------------------------------')
            epoch_num = epoch_num + 1
            
        return loss_list,valid_loss_list
            
    def test(self,input_array,output_array) : 
        accuracy = 0
        for (sample,output) in zip(input_array,output_array) : 
            
            a_list,h_list = self.forward_pass(sample)
            calc_output = h_list[-1]
            
            if np.where(calc_output == np.amax(calc_output)) == np.where(output == np.amax(output)) :
                accuracy = accuracy + 1
            
        accuracy = accuracy / len(input_array)    
        return accuracy

# %%
##### reading the data for the code #####
data = None
input_array = []
output_array = []

test_input_array = []
train_input_array= []

data = pd.read_csv('traingroup16.csv')

for i in range(len(data)) :
    input_array.append(np.array([data['x1'][i],data['x2'][i]]).reshape(2,1))
    if data['label'][i] == 0 :
        output_array.append(np.array([1.0,0.0,0.0]).reshape(3,1))
    if data['label'][i] == 1 :
        output_array.append(np.array([0.0,1.0,0.0]).reshape(3,1))
    if data['label'][i] == 2 :
        output_array.append(np.array([0.0,0.0,1.0]).reshape(3,1))  

test_input_array = input_array[int(np.floor(len(data)*3/4)):]
test_output_array = output_array[int(np.floor(len(data)*3/4)):]

train_input_array = input_array[:int(np.floor(len(data)*3/4))]
train_output_array = output_array[:int(np.floor(len(data)*3/4))]

# %%
nn = neural_network(2,[2,5,5,3],'cross_entropy',['tan_hyp','tan_hyp','softmax'],0.001,0.8)

list_avg_error,list_valid_avg_error = nn.train(train_input_array,train_output_array,test_input_array,test_output_array)

accuracy = nn.test(test_input_array,test_output_array)

print("Training Finished")
print("---------------------------------------------")
print("Accuracy : ",accuracy)
# Out:
# Epoch Number :  0
# Started
# ----------------------------------------
# Average Loss :  1.4961128115792788
# ----------------------------------------
# Epoch Number :  1
# Started
# ----------------------------------------
# Average Loss :  1.298851279446546
# ----------------------------------------
# Epoch Number :  2
# Started
# ----------------------------------------
# Average Loss :  1.1756610883804073
# ----------------------------------------
# Epoch Number :  3
# Started
# ----------------------------------------
# Average Loss :  1.099848017060967
# ----------------------------------------
# Epoch Number :  4
# Started
# ----------------------------------------
# Average Loss :  1.0475561888122795
# ----------------------------------------
# Epoch Number :  5
# Started
# ----------------------------------------
# Average Loss :  1.0098978212937963
# ----------------------------------------
# Epoch Number :  6
# Started
# ----------------------------------------
# Average Loss :  0.981509646173199
# ----------------------------------------
# Epoch Number :  7
# Started
# ----------------------------------------
# Average Loss :  0.9601215922251909
# ----------------------------------------
# Epoch Number :  8
# Started
# ----------------------------------------
# Average Loss :  0.9433288606187324
# ----------------------------------------
# Epoch Number :  9
# Started
# ----------------------------------------
# Average Loss :  0.9288634579640986
# ----------------------------------------
# Epoch Number :  10
# Started
# ----------------------------------------
# Average Loss :  0.9156016044949138
# ----------------------------------------
# Epoch Number :  11
# Started
# ----------------------------------------
# Average Loss :  0.9033469078055588
# ----------------------------------------
# Epoch Number :  12
# Started
# ----------------------------------------
# Average Loss :  0.8922108296121392
# ----------------------------------------
# Epoch Number :  13
# Started
# ----------------------------------------
# Average Loss :  0.8817672303361695
# ----------------------------------------
# Epoch Number :  14
# Started
# ----------------------------------------
# Average Loss :  0.872066286884652
# ----------------------------------------
# Epoch Number :  15
# Started
# ----------------------------------------
# Average Loss :  0.8630093064207565
# ----------------------------------------
# Epoch Number :  16
# Started
# ----------------------------------------
# Average Loss :  0.8542485883117221
# ----------------------------------------
# Epoch Number :  17
# Started
# ----------------------------------------
# Average Loss :  0.8459774291868066
# ----------------------------------------
# Epoch Number :  18
# Started
# ----------------------------------------
# Average Loss :  0.8385089027217582
# ----------------------------------------
# Epoch Number :  19
# Started
# ----------------------------------------
# Average Loss :  0.8309990528160223
# ----------------------------------------
# Epoch Number :  20
# Started
# ----------------------------------------
# Average Loss :  0.8231533984094751
# ----------------------------------------
# Epoch Number :  21
# Started
# ----------------------------------------
# Average Loss :  0.8148188099063045
# ----------------------------------------
# Epoch Number :  22
# Started
# ----------------------------------------
# Average Loss :  0.8057004181693701
# ----------------------------------------
# Epoch Number :  23
# Started
# ----------------------------------------
# Average Loss :  0.7962078361070113
# ----------------------------------------
# Epoch Number :  24
# Started
# ----------------------------------------
# Average Loss :  0.7882554923136083
# ----------------------------------------
# Epoch Number :  25
# Started
# ----------------------------------------
# Average Loss :  0.7812174259753115
# ----------------------------------------
# Epoch Number :  26
# Started
# ----------------------------------------
# Average Loss :  0.775027368437705
# ----------------------------------------
# Epoch Number :  27
# Started
# ----------------------------------------
# Average Loss :  0.7692846381344404
# ----------------------------------------
# Epoch Number :  28
# Started
# ----------------------------------------
# Average Loss :  0.763843222342257
# ----------------------------------------
# Epoch Number :  29
# Started
# ----------------------------------------
# Average Loss :  0.7586778631631729
# ----------------------------------------
# Epoch Number :  30
# Started
# ----------------------------------------
# Average Loss :  0.7537681605409822
# ----------------------------------------
# Epoch Number :  31
# Started
# ----------------------------------------
# Average Loss :  0.7490742289274681
# ----------------------------------------
# Epoch Number :  32
# Started
# ----------------------------------------
# Average Loss :  0.7445598228048522
# ----------------------------------------
# Epoch Number :  33
# Started
# ----------------------------------------
# Average Loss :  0.7402012227525908
# ----------------------------------------
# Epoch Number :  34
# Started
# ----------------------------------------
# Average Loss :  0.7359843788604545
# ----------------------------------------
# Epoch Number :  35
# Started
# ----------------------------------------
# Average Loss :  0.7319004969487232
# ----------------------------------------
# Epoch Number :  36
# Started
# ----------------------------------------
# Average Loss :  0.7279429548642667
# ----------------------------------------
# Epoch Number :  37
# Started
# ----------------------------------------
# Average Loss :  0.7241049649725817
# ----------------------------------------
# Epoch Number :  38
# Started
# ----------------------------------------
# Average Loss :  0.7203771656664724
# ----------------------------------------
# Epoch Number :  39
# Started
# ----------------------------------------
# Average Loss :  0.7167455516184443
# ----------------------------------------
# Epoch Number :  40
# Started
# ----------------------------------------
# Average Loss :  0.713191110265404
# ----------------------------------------
# Epoch Number :  41
# Started
# ----------------------------------------
# Average Loss :  0.7096916672555553
# ----------------------------------------
# Epoch Number :  42
# Started
# ----------------------------------------
# Average Loss :  0.7062245295359737
# ----------------------------------------
# Epoch Number :  43
# Started
# ----------------------------------------
# Average Loss :  0.7027682154790736
# ----------------------------------------
# Epoch Number :  44
# Started
# ----------------------------------------
# Average Loss :  0.6993031282670658
# ----------------------------------------
# Epoch Number :  45
# Started
# ----------------------------------------
# Average Loss :  0.6958123384794123
# ----------------------------------------
# Epoch Number :  46
# Started
# ----------------------------------------
# Average Loss :  0.6922839455497733
# ----------------------------------------
# Epoch Number :  47
# Started
# ----------------------------------------
# Average Loss :  0.6887163636982809
# ----------------------------------------
# Epoch Number :  48
# Started
# ----------------------------------------
# Average Loss :  0.6851265025487613
# ----------------------------------------
# Epoch Number :  49
# Started
# ----------------------------------------
# Average Loss :  0.6815551845120075
# ----------------------------------------
# Epoch Number :  50
# Started
# ----------------------------------------
# Average Loss :  0.6780588513134294
# ----------------------------------------
# Epoch Number :  51
# Started
# ----------------------------------------
# Average Loss :  0.6746915943129118
# ----------------------------------------
# Epoch Number :  52
# Started
# ----------------------------------------
# Average Loss :  0.6714949787903016
# ----------------------------------------
# Epoch Number :  53
# Started
# ----------------------------------------
# Average Loss :  0.66848948799286
# ----------------------------------------
# Epoch Number :  54
# Started
# ----------------------------------------
# Average Loss :  0.6656622926140052
# ----------------------------------------
# Epoch Number :  55
# Started
# ----------------------------------------
# Average Loss :  0.662959886795108
# ----------------------------------------
# Epoch Number :  56
# Started
# ----------------------------------------
# Average Loss :  0.6603016391328832
# ----------------------------------------
# Epoch Number :  57
# Started
# ----------------------------------------
# Average Loss :  0.6576066928203511
# ----------------------------------------
# Epoch Number :  58
# Started
# ----------------------------------------
# Average Loss :  0.6547918123949416
# ----------------------------------------
# Epoch Number :  59
# Started
# ----------------------------------------
# Average Loss :  0.6517522754623538
# ----------------------------------------
# Epoch Number :  60
# Started
# ----------------------------------------
# Average Loss :  0.6484746795698071
# ----------------------------------------
# Epoch Number :  61
# Started
# ----------------------------------------
# Average Loss :  0.6453286553411267
# ----------------------------------------
# Epoch Number :  62
# Started
# ----------------------------------------
# Average Loss :  0.6426043582363271
# ----------------------------------------
# Epoch Number :  63
# Started
# ----------------------------------------
# Average Loss :  0.6399047276887206
# ----------------------------------------
# Epoch Number :  64
# Started
# ----------------------------------------
# Average Loss :  0.6371726177088113
# ----------------------------------------
# Epoch Number :  65
# Started
# ----------------------------------------
# Average Loss :  0.6360657665795539
# ----------------------------------------
# Epoch Number :  66
# Started
# ----------------------------------------
# Average Loss :  0.6340182088404351
# ----------------------------------------
# Epoch Number :  67
# Started
# ----------------------------------------
# Average Loss :  0.6318602193323613
# ----------------------------------------
# Epoch Number :  68
# Started
# ----------------------------------------
# Average Loss :  0.6292213575830109
# ----------------------------------------
# Epoch Number :  69
# Started
# ----------------------------------------
# Average Loss :  0.6235244209283566
# ----------------------------------------
# Epoch Number :  70
# Started
# ----------------------------------------
# Average Loss :  0.6140882825487493
# ----------------------------------------
# Epoch Number :  71
# Started
# ----------------------------------------
# Average Loss :  0.6095176316748796
# ----------------------------------------
# Epoch Number :  72
# Started
# ----------------------------------------
# Average Loss :  0.6050882535638485
# ----------------------------------------
# Epoch Number :  73
# Started
# ----------------------------------------
# Average Loss :  0.6006829467783712
# ----------------------------------------
# Epoch Number :  74
# Started
# ----------------------------------------
# Average Loss :  0.595661395951877
# ----------------------------------------
# Epoch Number :  75
# Started
# ----------------------------------------
# Average Loss :  0.5912009480340639
# ----------------------------------------
# Epoch Number :  76
# Started
# ----------------------------------------
# Average Loss :  0.5875111118558088
# ----------------------------------------
# Epoch Number :  77
# Started
# ----------------------------------------
# Average Loss :  0.5843779022577964
# ----------------------------------------
# Epoch Number :  78
# Started
# ----------------------------------------
# Average Loss :  0.5819363626788863
# ----------------------------------------
# Epoch Number :  79
# Started
# ----------------------------------------
# Average Loss :  0.580861796597233
# ----------------------------------------
# Epoch Number :  80
# Started
# ----------------------------------------
# Average Loss :  0.5817156001234499
# ----------------------------------------
# Epoch Number :  81
# Started
# ----------------------------------------
# Average Loss :  0.5798026346301223
# ----------------------------------------
# Epoch Number :  82
# Started
# ----------------------------------------
# Average Loss :  0.577245733466448
# ----------------------------------------
# Epoch Number :  83
# Started
# ----------------------------------------
# Average Loss :  0.5706024022262545
# ----------------------------------------
# Epoch Number :  84
# Started
# ----------------------------------------
# Average Loss :  0.564045463466517
# ----------------------------------------
# Epoch Number :  85
# Started
# ----------------------------------------
# Average Loss :  0.5607481442242493
# ----------------------------------------
# Epoch Number :  86
# Started
# ----------------------------------------
# Average Loss :  0.5572835223351046
# ----------------------------------------
# Epoch Number :  87
# Started
# ----------------------------------------
# Average Loss :  0.5536341421089496
# ----------------------------------------
# Epoch Number :  88
# Started
# ----------------------------------------
# Average Loss :  0.5500027930862312
# ----------------------------------------
# Epoch Number :  89
# Started
# ----------------------------------------
# Average Loss :  0.5464750295573035
# ----------------------------------------
# Epoch Number :  90
# Started
# ----------------------------------------
# Average Loss :  0.5430922768268119
# ----------------------------------------
# Epoch Number :  91
# Started
# ----------------------------------------
# Average Loss :  0.539905910880941
# ----------------------------------------
# Epoch Number :  92
# Started
# ----------------------------------------
# Average Loss :  0.5369625208588863
# ----------------------------------------
# Epoch Number :  93
# Started
# ----------------------------------------
# Average Loss :  0.534259208323873
# ----------------------------------------
# Epoch Number :  94
# Started
# ----------------------------------------
# Average Loss :  0.5317512776686177
# ----------------------------------------
# Epoch Number :  95
# Started
# ----------------------------------------
# Average Loss :  0.529390577940102
# ----------------------------------------
# Epoch Number :  96
# Started
# ----------------------------------------
# Average Loss :  0.5271238407195922
# ----------------------------------------
# Epoch Number :  97
# Started
# ----------------------------------------
# Average Loss :  0.5248830696889571
# ----------------------------------------
# Epoch Number :  98
# Started
# ----------------------------------------
# Average Loss :  0.522617555780712
# ----------------------------------------
# Epoch Number :  99
# Started
# ----------------------------------------
# Average Loss :  0.520315713078023
# ----------------------------------------
# Epoch Number :  100
# Started
# ----------------------------------------
# Average Loss :  0.5179892618624166
# ----------------------------------------
# Epoch Number :  101
# Started
# ----------------------------------------
# Average Loss :  0.5156539682356496
# ----------------------------------------
# Epoch Number :  102
# Started
# ----------------------------------------
# Average Loss :  0.5133234501096209
# ----------------------------------------
# Epoch Number :  103
# Started
# ----------------------------------------
# Average Loss :  0.5110105236134551
# ----------------------------------------
# Epoch Number :  104
# Started
# ----------------------------------------
# Average Loss :  0.5087321563943229
# ----------------------------------------
# Epoch Number :  105
# Started
# ----------------------------------------
# Average Loss :  0.5065130894858046
# ----------------------------------------
# Epoch Number :  106
# Started
# ----------------------------------------
# Average Loss :  0.5043785642475227
# ----------------------------------------
# Epoch Number :  107
# Started
# ----------------------------------------
# Average Loss :  0.5023366534757373
# ----------------------------------------
# Epoch Number :  108
# Started
# ----------------------------------------
# Average Loss :  0.5003759159667029
# ----------------------------------------
# Epoch Number :  109
# Started
# ----------------------------------------
# Average Loss :  0.49847611051853846
# ----------------------------------------
# Epoch Number :  110
# Started
# ----------------------------------------
# Average Loss :  0.49658567160829076
# ----------------------------------------
# Epoch Number :  111
# Started
# ----------------------------------------
# Average Loss :  0.4947300048449637
# ----------------------------------------
# Epoch Number :  112
# Started
# ----------------------------------------
# Average Loss :  0.4927485754367517
# ----------------------------------------
# Epoch Number :  113
# Started
# ----------------------------------------
# Average Loss :  0.490290056112821
# ----------------------------------------
# Epoch Number :  114
# Started
# ----------------------------------------
# Average Loss :  0.4873904662884525
# ----------------------------------------
# Epoch Number :  115
# Started
# ----------------------------------------
# Average Loss :  0.48447192908488595
# ----------------------------------------
# Epoch Number :  116
# Started
# ----------------------------------------
# Average Loss :  0.48207663936470635
# ----------------------------------------
# Epoch Number :  117
# Started
# ----------------------------------------
# Average Loss :  0.48003485104719085
# ----------------------------------------
# Epoch Number :  118
# Started
# ----------------------------------------
# Average Loss :  0.4782317330833023
# ----------------------------------------
# Epoch Number :  119
# Started
# ----------------------------------------
# Average Loss :  0.4765484249568396
# ----------------------------------------
# Epoch Number :  120
# Started
# ----------------------------------------
# Average Loss :  0.4748872812572596
# ----------------------------------------
# Epoch Number :  121
# Started
# ----------------------------------------
# Average Loss :  0.47322334691099566
# ----------------------------------------
# Epoch Number :  122
# Started
# ----------------------------------------
# Average Loss :  0.4715800141184431
# ----------------------------------------
# Epoch Number :  123
# Started
# ----------------------------------------
# Average Loss :  0.46999588736764397
# ----------------------------------------
# Epoch Number :  124
# Started
# ----------------------------------------
# Average Loss :  0.46849917838606
# ----------------------------------------
# Epoch Number :  125
# Started
# ----------------------------------------
# Average Loss :  0.46709264134260176
# ----------------------------------------
# Epoch Number :  126
# Started
# ----------------------------------------
# Average Loss :  0.4657546510215168
# ----------------------------------------
# Epoch Number :  127
# Started
# ----------------------------------------
# Average Loss :  0.4644540841567424
# ----------------------------------------
# Epoch Number :  128
# Started
# ----------------------------------------
# Average Loss :  0.463165433376529
# ----------------------------------------
# Epoch Number :  129
# Started
# ----------------------------------------
# Average Loss :  0.4618725433427322
# ----------------------------------------
# Epoch Number :  130
# Started
# ----------------------------------------
# Average Loss :  0.460569866888208
# ----------------------------------------
# Epoch Number :  131
# Started
# ----------------------------------------
# Average Loss :  0.45929566119192095
# ----------------------------------------
# Epoch Number :  132
# Started
# ----------------------------------------
# Average Loss :  0.45823357472096743
# ----------------------------------------
# Epoch Number :  133
# Started
# ----------------------------------------
# Average Loss :  0.45774020903293045
# ----------------------------------------
# Epoch Number :  134
# Started
# ----------------------------------------
# Average Loss :  0.4576635589973484
# ----------------------------------------
# Epoch Number :  135
# Started
# ----------------------------------------
# Average Loss :  0.4574377930865861
# ----------------------------------------
# Epoch Number :  136
# Started
# ----------------------------------------
# Average Loss :  0.45764401421282724
# ----------------------------------------
# Epoch Number :  137
# Started
# ----------------------------------------
# Average Loss :  0.4577041662236767
# ----------------------------------------
# Epoch Number :  138
# Started
# ----------------------------------------
# Average Loss :  0.45852656208787257
# ----------------------------------------
# Epoch Number :  139
# Started
# ----------------------------------------
# Average Loss :  0.45770806390411123
# ----------------------------------------
# Epoch Number :  140
# Started
# ----------------------------------------
# Average Loss :  0.46064489336716813
# ----------------------------------------
# Epoch Number :  141
# Started
# ----------------------------------------
# Average Loss :  0.4621374360870594
# ----------------------------------------
# Epoch Number :  142
# Started
# ----------------------------------------
# Average Loss :  0.4561814729583239
# ----------------------------------------
# Epoch Number :  143
# Started
# ----------------------------------------
# Average Loss :  0.4518739607619345
# ----------------------------------------
# Epoch Number :  144
# Started
# ----------------------------------------
# Average Loss :  0.45436283595934235
# ----------------------------------------
# Epoch Number :  145
# Started
# ----------------------------------------
# Average Loss :  0.44964423987428237
# ----------------------------------------
# Epoch Number :  146
# Started
# ----------------------------------------
# Average Loss :  0.44863771160144394
# ----------------------------------------
# Epoch Number :  147
# Started
# ----------------------------------------
# Average Loss :  0.44731345744149875
# ----------------------------------------
# Epoch Number :  148
# Started
# ----------------------------------------
# Average Loss :  0.44294018967104015
# ----------------------------------------
# Epoch Number :  149
# Started
# ----------------------------------------
# Average Loss :  0.4386582097615811
# ----------------------------------------
# Epoch Number :  150
# Started
# ----------------------------------------
# Average Loss :  0.43731634238691175
# ----------------------------------------
# Epoch Number :  151
# Started
# ----------------------------------------
# Average Loss :  0.43405385604592167
# ----------------------------------------
# Epoch Number :  152
# Started
# ----------------------------------------
# Average Loss :  0.4312813075495654
# ----------------------------------------
# Epoch Number :  153
# Started
# ----------------------------------------
# Average Loss :  0.4305491202827279
# ----------------------------------------
# Epoch Number :  154
# Started
# ----------------------------------------
# Average Loss :  0.4282404139780254
# ----------------------------------------
# Epoch Number :  155
# Started
# ----------------------------------------
# Average Loss :  0.42440555376951256
# ----------------------------------------
# Epoch Number :  156
# Started
# ----------------------------------------
# Average Loss :  0.422004545053119
# ----------------------------------------
# Epoch Number :  157
# Started
# ----------------------------------------
# Average Loss :  0.4206131843830808
# ----------------------------------------
# Epoch Number :  158
# Started
# ----------------------------------------
# Average Loss :  0.4195116452633541
# ----------------------------------------
# Epoch Number :  159
# Started
# ----------------------------------------
# Average Loss :  0.41861939924796837
# ----------------------------------------
# Epoch Number :  160
# Started
# ----------------------------------------
# Average Loss :  0.41782112590992543
# ----------------------------------------
# Epoch Number :  161
# Started
# ----------------------------------------
# Average Loss :  0.4171090884444136
# ----------------------------------------
# Epoch Number :  162
# Started
# ----------------------------------------
# Average Loss :  0.41642917475523233
# ----------------------------------------
# Epoch Number :  163
# Started
# ----------------------------------------
# Average Loss :  0.41576855642698035
# ----------------------------------------
# Epoch Number :  164
# Started
# ----------------------------------------
# Average Loss :  0.4150847243616807
# ----------------------------------------
# Epoch Number :  165
# Started
# ----------------------------------------
# Average Loss :  0.41434275584645236
# ----------------------------------------
# Epoch Number :  166
# Started
# ----------------------------------------
# Average Loss :  0.41351279421445297
# ----------------------------------------
# Epoch Number :  167
# Started
# ----------------------------------------
# Average Loss :  0.4126384759675111
# ----------------------------------------
# Epoch Number :  168
# Started
# ----------------------------------------
# Average Loss :  0.41173650194629713
# ----------------------------------------
# Epoch Number :  169
# Started
# ----------------------------------------
# Average Loss :  0.41071906053538043
# ----------------------------------------
# Epoch Number :  170
# Started
# ----------------------------------------
# Average Loss :  0.4094835060429018
# ----------------------------------------
# Epoch Number :  171
# Started
# ----------------------------------------
# Average Loss :  0.4080208771375575
# ----------------------------------------
# Epoch Number :  172
# Started
# ----------------------------------------
# Average Loss :  0.40650620256858244
# ----------------------------------------
# Epoch Number :  173
# Started
# ----------------------------------------
# Average Loss :  0.40514384498443623
# ----------------------------------------
# Epoch Number :  174
# Started
# ----------------------------------------
# Average Loss :  0.40405566707364016
# ----------------------------------------
# Epoch Number :  175
# Started
# ----------------------------------------
# Average Loss :  0.40329139575420286
# ----------------------------------------
# Epoch Number :  176
# Started
# ----------------------------------------
# Average Loss :  0.40272879598122585
# ----------------------------------------
# Epoch Number :  177
# Started
# ----------------------------------------
# Average Loss :  0.4021078252131472
# ----------------------------------------
# Epoch Number :  178
# Started
# ----------------------------------------
# Average Loss :  0.4013366269224482
# ----------------------------------------
# Epoch Number :  179
# Started
# ----------------------------------------
# Average Loss :  0.4004626317383435
# ----------------------------------------
# Epoch Number :  180
# Started
# ----------------------------------------
# Average Loss :  0.39954605574820384
# ----------------------------------------
# Epoch Number :  181
# Started
# ----------------------------------------
# Average Loss :  0.3986302803897984
# ----------------------------------------
# Epoch Number :  182
# Started
# ----------------------------------------
# Average Loss :  0.39773546569104934
# ----------------------------------------
# Epoch Number :  183
# Started
# ----------------------------------------
# Average Loss :  0.3968674119945972
# ----------------------------------------
# Epoch Number :  184
# Started
# ----------------------------------------
# Average Loss :  0.396024882778271
# ----------------------------------------
# Epoch Number :  185
# Started
# ----------------------------------------
# Average Loss :  0.39520413536566673
# ----------------------------------------
# Epoch Number :  186
# Started
# ----------------------------------------
# Average Loss :  0.3944219438638076
# ----------------------------------------
# Epoch Number :  187
# Started
# ----------------------------------------
# Average Loss :  0.39378015921249515
# ----------------------------------------
# Epoch Number :  188
# Started
# ----------------------------------------
# Average Loss :  0.3932016023160985
# ----------------------------------------
# Epoch Number :  189
# Started
# ----------------------------------------
# Average Loss :  0.3925120389950058
# ----------------------------------------
# Epoch Number :  190
# Started
# ----------------------------------------
# Average Loss :  0.39192043311214003
# ----------------------------------------
# Epoch Number :  191
# Started
# ----------------------------------------
# Average Loss :  0.39123201432993887
# ----------------------------------------
# Epoch Number :  192
# Started
# ----------------------------------------
# Average Loss :  0.39089215067363914
# ----------------------------------------
# Epoch Number :  193
# Started
# ----------------------------------------
# Average Loss :  0.39017341395632443
# ----------------------------------------
# Epoch Number :  194
# Started
# ----------------------------------------
# Average Loss :  0.39047049965817077
# ----------------------------------------
# Epoch Number :  195
# Started
# ----------------------------------------
# Average Loss :  0.3888275925868605
# ----------------------------------------
# Epoch Number :  196
# Started
# ----------------------------------------
# Average Loss :  0.3911553471308023
# ----------------------------------------
# Epoch Number :  197
# Started
# ----------------------------------------
# Average Loss :  0.3862142156044486
# ----------------------------------------
# Epoch Number :  198
# Started
# ----------------------------------------
# Average Loss :  0.39367526391185226
# ----------------------------------------
# Epoch Number :  199
# Started
# ----------------------------------------
# Average Loss :  0.38421245879958477
# ----------------------------------------
# Epoch Number :  200
# Started
# ----------------------------------------
# Average Loss :  0.3937700842368235
# ----------------------------------------
# Epoch Number :  201
# Started
# ----------------------------------------
# Average Loss :  0.38357953202621814
# ----------------------------------------
# Epoch Number :  202
# Started
# ----------------------------------------
# Average Loss :  0.3919721957163597
# ----------------------------------------
# Epoch Number :  203
# Started
# ----------------------------------------
# Average Loss :  0.38302440927733195
# ----------------------------------------
# Epoch Number :  204
# Started
# ----------------------------------------
# Average Loss :  0.3903000381237361
# ----------------------------------------
# Epoch Number :  205
# Started
# ----------------------------------------
# Average Loss :  0.3825373919831274
# ----------------------------------------
# Epoch Number :  206
# Started
# ----------------------------------------
# Average Loss :  0.38826935017055064
# ----------------------------------------
# Epoch Number :  207
# Started
# ----------------------------------------
# Average Loss :  0.3823733406938184
# ----------------------------------------
# Epoch Number :  208
# Started
# ----------------------------------------
# Average Loss :  0.38573681011222116
# ----------------------------------------
# Epoch Number :  209
# Started
# ----------------------------------------
# Average Loss :  0.3832391523826623
# ----------------------------------------
# Epoch Number :  210
# Started
# ----------------------------------------
# Average Loss :  0.38256492110325335
# ----------------------------------------
# Epoch Number :  211
# Started
# ----------------------------------------
# Average Loss :  0.381916992532027
# ----------------------------------------
# Epoch Number :  212
# Started
# ----------------------------------------
# Average Loss :  0.381316115959959
# ----------------------------------------
# Epoch Number :  213
# Started
# ----------------------------------------
# Average Loss :  0.38074116084469495
# ----------------------------------------
# Epoch Number :  214
# Started
# ----------------------------------------
# Average Loss :  0.38020720818713005
# ----------------------------------------
# Epoch Number :  215
# Started
# ----------------------------------------
# Average Loss :  0.37962021782064836
# ----------------------------------------
# Epoch Number :  216
# Started
# ----------------------------------------
# Average Loss :  0.38016886490788465
# ----------------------------------------
# Epoch Number :  217
# Started
# ----------------------------------------
# Average Loss :  0.3780309721476209
# ----------------------------------------
# Epoch Number :  218
# Started
# ----------------------------------------
# Average Loss :  0.377504690651515
# ----------------------------------------
# Epoch Number :  219
# Started
# ----------------------------------------
# Average Loss :  0.37711315191067385
# ----------------------------------------
# Epoch Number :  220
# Started
# ----------------------------------------
# Average Loss :  0.3764077261657762
# ----------------------------------------
# Epoch Number :  221
# Started
# ----------------------------------------
# Average Loss :  0.37581350374312916
# ----------------------------------------
# Epoch Number :  222
# Started
# ----------------------------------------
# Average Loss :  0.3751664020816546
# ----------------------------------------
# Epoch Number :  223
# Started
# ----------------------------------------
# Average Loss :  0.3745796862516143
# ----------------------------------------
# Epoch Number :  224
# Started
# ----------------------------------------
# Average Loss :  0.3740070689592619
# ----------------------------------------
# Epoch Number :  225
# Started
# ----------------------------------------
# Average Loss :  0.37346042407521923
# ----------------------------------------
# Epoch Number :  226
# Started
# ----------------------------------------
# Average Loss :  0.37293852936493554
# ----------------------------------------
# Epoch Number :  227
# Started
# ----------------------------------------
# Average Loss :  0.37243997813673074
# ----------------------------------------
# Epoch Number :  228
# Started
# ----------------------------------------
# Average Loss :  0.37196524758150523
# ----------------------------------------
# Epoch Number :  229
# Started
# ----------------------------------------
# Average Loss :  0.37151279127269266
# ----------------------------------------
# Epoch Number :  230
# Started
# ----------------------------------------
# Average Loss :  0.3710815750179118
# ----------------------------------------
# Epoch Number :  231
# Started
# ----------------------------------------
# Average Loss :  0.37067023393887916
# ----------------------------------------
# Epoch Number :  232
# Started
# ----------------------------------------
# Average Loss :  0.37027738040625874
# ----------------------------------------
# Epoch Number :  233
# Started
# ----------------------------------------
# Average Loss :  0.3699015930226496
# ----------------------------------------
# Epoch Number :  234
# Started
# ----------------------------------------
# Average Loss :  0.3695414531601535
# ----------------------------------------
# Epoch Number :  235
# Started
# ----------------------------------------
# Average Loss :  0.3691955789597217
# ----------------------------------------
# Epoch Number :  236
# Started
# ----------------------------------------
# Average Loss :  0.3688626562092704
# ----------------------------------------
# Epoch Number :  237
# Started
# ----------------------------------------
# Average Loss :  0.3685414697742749
# ----------------------------------------
# Epoch Number :  238
# Started
# ----------------------------------------
# Average Loss :  0.3682309354315341
# ----------------------------------------
# Epoch Number :  239
# Started
# ----------------------------------------
# Average Loss :  0.3679301351276203
# ----------------------------------------
# Epoch Number :  240
# Started
# ----------------------------------------
# Average Loss :  0.3676383596406361
# ----------------------------------------
# Epoch Number :  241
# Started
# ----------------------------------------
# Average Loss :  0.36735516346680525
# ----------------------------------------
# Epoch Number :  242
# Started
# ----------------------------------------
# Average Loss :  0.36708043621294045
# ----------------------------------------
# Epoch Number :  243
# Started
# ----------------------------------------
# Average Loss :  0.36681449139517347
# ----------------------------------------
# Epoch Number :  244
# Started
# ----------------------------------------
# Average Loss :  0.3665581629779629
# ----------------------------------------
# Epoch Number :  245
# Started
# ----------------------------------------
# Average Loss :  0.3663128733321067
# ----------------------------------------
# Epoch Number :  246
# Started
# ----------------------------------------
# Average Loss :  0.36608058413552913
# ----------------------------------------
# Epoch Number :  247
# Started
# ----------------------------------------
# Average Loss :  0.3658634849011038
# ----------------------------------------
# Epoch Number :  248
# Started
# ----------------------------------------
# Average Loss :  0.36566334021665725
# ----------------------------------------
# Epoch Number :  249
# Started
# ----------------------------------------
# Average Loss :  0.3654808206704985
# ----------------------------------------
# Epoch Number :  250
# Started
# ----------------------------------------
# Average Loss :  0.3653156120174239
# ----------------------------------------
# Epoch Number :  251
# Started
# ----------------------------------------
# Average Loss :  0.36516738846502284
# ----------------------------------------
# Epoch Number :  252
# Started
# ----------------------------------------
# Average Loss :  0.36503612130858243
# ----------------------------------------
# Epoch Number :  253
# Started
# ----------------------------------------
# Average Loss :  0.36492099212185697
# ----------------------------------------
# Epoch Number :  254
# Started
# ----------------------------------------
# Average Loss :  0.36481958261007025
# ----------------------------------------
# Epoch Number :  255
# Started
# ----------------------------------------
# Average Loss :  0.3647283617925728
# ----------------------------------------
# Epoch Number :  256
# Started
# ----------------------------------------
# Average Loss :  0.3646435366221959
# ----------------------------------------
# Epoch Number :  257
# Started
# ----------------------------------------
# Average Loss :  0.3645615003769824
# ----------------------------------------
# Epoch Number :  258
# Started
# ----------------------------------------
# Average Loss :  0.3644789995407707
# ----------------------------------------
# Epoch Number :  259
# Started
# ----------------------------------------
# Average Loss :  0.3643932707177874
# ----------------------------------------
# Epoch Number :  260
# Started
# ----------------------------------------
# Average Loss :  0.3643021905971183
# ----------------------------------------
# Epoch Number :  261
# Started
# ----------------------------------------
# Average Loss :  0.364204365513543
# ----------------------------------------
# Epoch Number :  262
# Started
# ----------------------------------------
# Average Loss :  0.36409910552429087
# ----------------------------------------
# Epoch Number :  263
# Started
# ----------------------------------------
# Average Loss :  0.363986296747018
# ----------------------------------------
# Epoch Number :  264
# Started
# ----------------------------------------
# Average Loss :  0.3638662275336704
# ----------------------------------------
# Epoch Number :  265
# Started
# ----------------------------------------
# Average Loss :  0.3637394217094326
# ----------------------------------------
# Epoch Number :  266
# Started
# ----------------------------------------
# Average Loss :  0.3636065080446532
# ----------------------------------------
# Epoch Number :  267
# Started
# ----------------------------------------
# Average Loss :  0.36346813244328047
# ----------------------------------------
# Epoch Number :  268
# Started
# ----------------------------------------
# Average Loss :  0.3633249066704112
# ----------------------------------------
# Epoch Number :  269
# Started
# ----------------------------------------
# Average Loss :  0.36317738344126466
# ----------------------------------------
# Epoch Number :  270
# Started
# ----------------------------------------
# Average Loss :  0.36302604836533214
# ----------------------------------------
# Epoch Number :  271
# Started
# ----------------------------------------
# Average Loss :  0.3628713215342879
# ----------------------------------------
# Epoch Number :  272
# Started
# ----------------------------------------
# Average Loss :  0.36271356390046144
# ----------------------------------------
# Epoch Number :  273
# Started
# ----------------------------------------
# Average Loss :  0.3625530854562594
# ----------------------------------------
# Epoch Number :  274
# Started
# ----------------------------------------
# Average Loss :  0.36239015352155524
# ----------------------------------------
# Epoch Number :  275
# Started
# ----------------------------------------
# Average Loss :  0.36222500027821136
# ----------------------------------------
# Epoch Number :  276
# Started
# ----------------------------------------
# Average Loss :  0.36205782919241364
# ----------------------------------------
# Epoch Number :  277
# Started
# ----------------------------------------
# Average Loss :  0.3618888202498933
# ----------------------------------------
# Epoch Number :  278
# Started
# ----------------------------------------
# Average Loss :  0.36171813407864084
# ----------------------------------------
# Epoch Number :  279
# Started
# ----------------------------------------
# Average Loss :  0.36154591510336376
# ----------------------------------------
# Epoch Number :  280
# Started
# ----------------------------------------
# Average Loss :  0.36137229390013964
# ----------------------------------------
# Epoch Number :  281
# Started
# ----------------------------------------
# Average Loss :  0.3611973889194824
# ----------------------------------------
# Epoch Number :  282
# Started
# ----------------------------------------
# Average Loss :  0.3610213077334594
# ----------------------------------------
# Epoch Number :  283
# Started
# ----------------------------------------
# Average Loss :  0.36084414794456593
# ----------------------------------------
# Epoch Number :  284
# Started
# ----------------------------------------
# Average Loss :  0.360665997874659
# ----------------------------------------
# Epoch Number :  285
# Started
# ----------------------------------------
# Average Loss :  0.3604869371337099
# ----------------------------------------
# Epoch Number :  286
# Started
# ----------------------------------------
# Average Loss :  0.3603070371520961
# ----------------------------------------
# Epoch Number :  287
# Started
# ----------------------------------------
# Average Loss :  0.36012636174792156
# ----------------------------------------
# Epoch Number :  288
# Started
# ----------------------------------------
# Average Loss :  0.35994496779386587
# ----------------------------------------
# Epoch Number :  289
# Started
# ----------------------------------------
# Average Loss :  0.3597629060480223
# ----------------------------------------
# Epoch Number :  290
# Started
# ----------------------------------------
# Average Loss :  0.3595802222223223
# ----------------------------------------
# Epoch Number :  291
# Started
# ----------------------------------------
# Average Loss :  0.35939695838352703
# ----------------------------------------
# Epoch Number :  292
# Started
# ----------------------------------------
# Average Loss :  0.3592131548199669
# ----------------------------------------
# Epoch Number :  293
# Started
# ----------------------------------------
# Average Loss :  0.3590288525689793
# ----------------------------------------
# Epoch Number :  294
# Started
# ----------------------------------------
# Average Loss :  0.3588440968957894
# ----------------------------------------
# Epoch Number :  295
# Started
# ----------------------------------------
# Average Loss :  0.35865894216029015
# ----------------------------------------
# Epoch Number :  296
# Started
# ----------------------------------------
# Average Loss :  0.3584734587283699
# ----------------------------------------
# Epoch Number :  297
# Started
# ----------------------------------------
# Average Loss :  0.3582877429158205
# ----------------------------------------
# Epoch Number :  298
# Started
# ----------------------------------------
# Average Loss :  0.35810193144973645
# ----------------------------------------
# Epoch Number :  299
# Started
# ----------------------------------------
# Average Loss :  0.35791622266974593
# ----------------------------------------
# Epoch Number :  300
# Started
# ----------------------------------------
# Average Loss :  0.3577309077624277
# ----------------------------------------
# Epoch Number :  301
# Started
# ----------------------------------------
# Average Loss :  0.35754641680888566
# ----------------------------------------
# Epoch Number :  302
# Started
# ----------------------------------------
# Average Loss :  0.35736338629740433
# ----------------------------------------
# Epoch Number :  303
# Started
# ----------------------------------------
# Average Loss :  0.35718275658110743
# ----------------------------------------
# Epoch Number :  304
# Started
# ----------------------------------------
# Average Loss :  0.35700590800687565
# ----------------------------------------
# Epoch Number :  305
# Started
# ----------------------------------------
# Average Loss :  0.35683483893485907
# ----------------------------------------
# Epoch Number :  306
# Started
# ----------------------------------------
# Average Loss :  0.35667236820281845
# ----------------------------------------
# Epoch Number :  307
# Started
# ----------------------------------------
# Average Loss :  0.3565222918886756
# ----------------------------------------
# Epoch Number :  308
# Started
# ----------------------------------------
# Average Loss :  0.35638932087989844
# ----------------------------------------
# Epoch Number :  309
# Started
# ----------------------------------------
# Average Loss :  0.3562784844286007
# ----------------------------------------
# Epoch Number :  310
# Started
# ----------------------------------------
# Average Loss :  0.3561936259802781
# ----------------------------------------
# Epoch Number :  311
# Started
# ----------------------------------------
# Average Loss :  0.3561349220221071
# ----------------------------------------
# Epoch Number :  312
# Started
# ----------------------------------------
# Average Loss :  0.35609624336053247
# ----------------------------------------
# Epoch Number :  313
# Started
# ----------------------------------------
# Average Loss :  0.3560641767286842
# ----------------------------------------
# Epoch Number :  314
# Started
# ----------------------------------------
# Average Loss :  0.35602033769807045
# ----------------------------------------
# Epoch Number :  315
# Started
# ----------------------------------------
# Average Loss :  0.3559467183830186
# ----------------------------------------
# Epoch Number :  316
# Started
# ----------------------------------------
# Average Loss :  0.35583150519393614
# ----------------------------------------
# Epoch Number :  317
# Started
# ----------------------------------------
# Average Loss :  0.3556718812107944
# ----------------------------------------
# Epoch Number :  318
# Started
# ----------------------------------------
# Average Loss :  0.35547243929634387
# ----------------------------------------
# Epoch Number :  319
# Started
# ----------------------------------------
# Average Loss :  0.35524146646995697
# ----------------------------------------
# Epoch Number :  320
# Started
# ----------------------------------------
# Average Loss :  0.35498792841996607
# ----------------------------------------
# Epoch Number :  321
# Started
# ----------------------------------------
# Average Loss :  0.35471986827048485
# ----------------------------------------
# Epoch Number :  322
# Started
# ----------------------------------------
# Average Loss :  0.35444377717902376
# ----------------------------------------
# Epoch Number :  323
# Started
# ----------------------------------------
# Average Loss :  0.35416451110751057
# ----------------------------------------
# Epoch Number :  324
# Started
# ----------------------------------------
# Average Loss :  0.35388548903542977
# ----------------------------------------
# Epoch Number :  325
# Started
# ----------------------------------------
# Average Loss :  0.35360900309694887
# ----------------------------------------
# Epoch Number :  326
# Started
# ----------------------------------------
# Average Loss :  0.35333653244492746
# ----------------------------------------
# Epoch Number :  327
# Started
# ----------------------------------------
# Average Loss :  0.3530690049442563
# ----------------------------------------
# Epoch Number :  328
# Started
# ----------------------------------------
# Average Loss :  0.3528069898144756
# ----------------------------------------
# Epoch Number :  329
# Started
# ----------------------------------------
# Average Loss :  0.35255082717355923
# ----------------------------------------
# Epoch Number :  330
# Started
# ----------------------------------------
# Average Loss :  0.35230070938498037
# ----------------------------------------
# Epoch Number :  331
# Started
# ----------------------------------------
# Average Loss :  0.3520567296496817
# ----------------------------------------
# Epoch Number :  332
# Started
# ----------------------------------------
# Average Loss :  0.3518189101563745
# ----------------------------------------
# Epoch Number :  333
# Started
# ----------------------------------------
# Average Loss :  0.3515872182939764
# ----------------------------------------
# Epoch Number :  334
# Started
# ----------------------------------------
# Average Loss :  0.3513615762585972
# ----------------------------------------
# Epoch Number :  335
# Started
# ----------------------------------------
# Average Loss :  0.35114186718168344
# ----------------------------------------
# Epoch Number :  336
# Started
# ----------------------------------------
# Average Loss :  0.3509279395316615
# ----------------------------------------
# Epoch Number :  337
# Started
# ----------------------------------------
# Average Loss :  0.3507196107433713
# ----------------------------------------
# Epoch Number :  338
# Started
# ----------------------------------------
# Average Loss :  0.3505166705796448
# ----------------------------------------
# Epoch Number :  339
# Started
# ----------------------------------------
# Average Loss :  0.3503188844715469
# ----------------------------------------
# Epoch Number :  340
# Started
# ----------------------------------------
# Average Loss :  0.3501259969293062
# ----------------------------------------
# Epoch Number :  341
# Started
# ----------------------------------------
# Average Loss :  0.34993773502110365
# ----------------------------------------
# Epoch Number :  342
# Started
# ----------------------------------------
# Average Loss :  0.3497538118627114
# ----------------------------------------
# Epoch Number :  343
# Started
# ----------------------------------------
# Average Loss :  0.3495739300386241
# ----------------------------------------
# Epoch Number :  344
# Started
# ----------------------------------------
# Average Loss :  0.3493977848782618
# ----------------------------------------
# Epoch Number :  345
# Started
# ----------------------------------------
# Average Loss :  0.34922506753360233
# ----------------------------------------
# Epoch Number :  346
# Started
# ----------------------------------------
# Average Loss :  0.34905546784115166
# ----------------------------------------
# Epoch Number :  347
# Started
# ----------------------------------------
# Average Loss :  0.3488886769982335
# ----------------------------------------
# Epoch Number :  348
# Started
# ----------------------------------------
# Average Loss :  0.34872439013843215
# ----------------------------------------
# Epoch Number :  349
# Started
# ----------------------------------------
# Average Loss :  0.34856230895384055
# ----------------------------------------
# Epoch Number :  350
# Started
# ----------------------------------------
# Average Loss :  0.34840214458315255
# ----------------------------------------
# Epoch Number :  351
# Started
# ----------------------------------------
# Average Loss :  0.348243621066086
# ----------------------------------------
# Epoch Number :  352
# Started
# ----------------------------------------
# Average Loss :  0.34808647975574236
# ----------------------------------------
# Epoch Number :  353
# Started
# ----------------------------------------
# Average Loss :  0.3479304851778995
# ----------------------------------------
# Epoch Number :  354
# Started
# ----------------------------------------
# Average Loss :  0.34777543291914
# ----------------------------------------
# Epoch Number :  355
# Started
# ----------------------------------------
# Average Loss :  0.34762116019128697
# ----------------------------------------
# Epoch Number :  356
# Started
# ----------------------------------------
# Average Loss :  0.3474675597155086
# ----------------------------------------
# Epoch Number :  357
# Started
# ----------------------------------------
# Average Loss :  0.3473145974247224
# ----------------------------------------
# Epoch Number :  358
# Started
# ----------------------------------------
# Average Loss :  0.34716233409036035
# ----------------------------------------
# Epoch Number :  359
# Started
# ----------------------------------------
# Average Loss :  0.3470109501960032
# ----------------------------------------
# Epoch Number :  360
# Started
# ----------------------------------------
# Average Loss :  0.34686077205376237
# ----------------------------------------
# Epoch Number :  361
# Started
# ----------------------------------------
# Average Loss :  0.3467122952153211
# ----------------------------------------
# Epoch Number :  362
# Started
# ----------------------------------------
# Average Loss :  0.34656619886217627
# ----------------------------------------
# Epoch Number :  363
# Started
# ----------------------------------------
# Average Loss :  0.34642334284793747
# ----------------------------------------
# Epoch Number :  364
# Started
# ----------------------------------------
# Average Loss :  0.34628473907208696
# ----------------------------------------
# Epoch Number :  365
# Started
# ----------------------------------------
# Average Loss :  0.346151493243113
# ----------------------------------------
# Epoch Number :  366
# Started
# ----------------------------------------
# Average Loss :  0.34602472339219864
# ----------------------------------------
# Epoch Number :  367
# Started
# ----------------------------------------
# Average Loss :  0.3459054755778407
# ----------------------------------------
# Epoch Number :  368
# Started
# ----------------------------------------
# Average Loss :  0.34579466733130415
# ----------------------------------------
# Epoch Number :  369
# Started
# ----------------------------------------
# Average Loss :  0.3456930860969619
# ----------------------------------------
# Epoch Number :  370
# Started
# ----------------------------------------
# Average Loss :  0.3456014522870389
# ----------------------------------------
# Epoch Number :  371
# Started
# ----------------------------------------
# Average Loss :  0.3455205380840525
# ----------------------------------------
# Epoch Number :  372
# Started
# ----------------------------------------
# Average Loss :  0.34545133215587503
# ----------------------------------------
# Epoch Number :  373
# Started
# ----------------------------------------
# Average Loss :  0.34539526532635256
# ----------------------------------------
# Epoch Number :  374
# Started
# ----------------------------------------
# Average Loss :  0.34535456519412017
# ----------------------------------------
# Epoch Number :  375
# Started
# ----------------------------------------
# Average Loss :  0.3453329152607386
# ----------------------------------------
# Epoch Number :  376
# Started
# ----------------------------------------
# Average Loss :  0.34533687156282444
# ----------------------------------------
# Training Finished
# ---------------------------------------------
# Accuracy :  0.831858407079646
